# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
#

# %%
df = pd.read_csv('/content/medicine_dataset.csv')

# %%
df.head(10)
# Out:
#            Name        Category Dosage Form Strength  \
# 0   Acetocillin    Antidiabetic       Cream   938 mg
# 1  Ibuprocillin       Antiviral   Injection   337 mg
# 2    Dextrophen      Antibiotic    Ointment   333 mg
# 3   Clarinazole      Antifungal       Syrup   362 mg
# 4   Amoxicillin      Antifungal      Tablet   802 mg
# 5   Ibupromycin      Antibiotic   Injection   140 mg
# 6       Metovir     Antipyretic    Ointment   641 mg
# 7     Ibuprovir  Antidepressant       Syrup   758 mg
# 8     Cefcillin     Antipyretic      Tablet   954 mg
# 9    Acetomycin       Analgesic     Inhaler   838 mg
#
#                             Manufacturer Indication    Classification
# 0                       Roche Holding AG      Virus  Over-the-Counter
# 1                            CSL Limited  Infection  Over-the-Counter
# 2                      Johnson & Johnson      Wound      Prescription
# 3                            AbbVie Inc.       Pain      Prescription
# ...

# %%
df.shape
# Out:
# (50000, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            50000 non-null  object
#  1   Category        50000 non-null  object
#  2   Dosage Form     50000 non-null  object
#  3   Strength        50000 non-null  object
#  4   Manufacturer    50000 non-null  object
#  5   Indication      50000 non-null  object
#  6   Classification  50000 non-null  object
# dtypes: object(7)
# memory usage: 2.7+ MB

# %%
df.describe()
# Out:
#               Name        Category Dosage Form Strength  \
# count        50000           50000       50000    50000
# unique          64               8           8      999
# top     Metostatin  Antidepressant     Inhaler   347 mg
# freq           860            6354        6364       77
#
#                      Manufacturer Indication    Classification
# count                       50000      50000             50000
# unique                         20          8                 2
# top     Boehringer Ingelheim GmbH  Infection  Over-the-Counter
# freq                         2587       6393             25015

# %%
df.isnull().sum()
# Out:
# Name              0
# Category          0
# Dosage Form       0
# Strength          0
# Manufacturer      0
# Indication        0
# Classification    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop('Name',axis=1,inplace=True)

# %%
df.head(13)
# Out:
#           Category Dosage Form Strength  \
# 0     Antidiabetic       Cream   938 mg
# 1        Antiviral   Injection   337 mg
# 2       Antibiotic    Ointment   333 mg
# 3       Antifungal       Syrup   362 mg
# 4       Antifungal      Tablet   802 mg
# 5       Antibiotic   Injection   140 mg
# 6      Antipyretic    Ointment   641 mg
# 7   Antidepressant       Syrup   758 mg
# 8      Antipyretic      Tablet   954 mg
# 9        Analgesic     Inhaler   838 mg
# 10      Antifungal    Ointment   422 mg
# 11     Antipyretic    Ointment   575 mg
# 12       Antiviral    Ointment   451 mg
#
#                              Manufacturer Indication    Classification
# 0                        Roche Holding AG      Virus  Over-the-Counter
# 1                             CSL Limited  Infection  Over-the-Counter
# 2                       Johnson & Johnson      Wound      Prescription
# 3                             AbbVie Inc.       Pain      Prescription
# ...

# %%
plt.pie(df['Category'].value_counts(),labels=df['Category'].value_counts().index)
plt.show()

# %%
plt.pie(df['Dosage Form'].value_counts(),labels = df['Dosage Form'].value_counts().index)
plt.show()

# %%
df['Classification'].value_counts()
# Out:
# Classification
# Over-the-Counter    25015
# Prescription        24985
# Name: count, dtype: int64

# %%
df['Dosage Form'].value_counts()
# Out:
# Dosage Form
# Inhaler      6364
# Ointment     6284
# Capsule      6271
# Injection    6258
# Drops        6236
# Tablet       6234
# Syrup        6195
# Cream        6158
# Name: count, dtype: int64

# %%
sns.histplot(df['Dosage Form'])
plt.show()

# %%
sns.histplot(df['Classification'])
plt.show()

# %%
sns.histplot(x='Dosage Form',data=df,hue='Classification')
plt.show()

# %%
sns.histplot(x='Dosage Form',data=df,hue='Category')
plt.show()

# %%
df['Strength'].max()
# Out:
# '999 mg'

# %%
plt.figure(figsize=(12,10))
sns.violinplot(x='Dosage Form',y='Strength',data=df)
plt.show()
plt.yticks(np.arange(0,1000,100))
# Out:
# ([<matplotlib.axis.YTick at 0x79816665d060>,
# ...
#  [Text(0, 0, '0'),
#   Text(0, 100, '100'),
#   Text(0, 200, '200'),
#   Text(0, 300, '300'),
#   Text(0, 400, '400'),
#   Text(0, 500, '500'),
#   Text(0, 600, '600'),
#   Text(0, 700, '700'),
#   Text(0, 800, '800'),
#   Text(0, 900, '900')])

# %%
df.columns
# Out:
# Index(['Category', 'Dosage Form', 'Strength', 'Manufacturer', 'Indication',
#        'Classification'],
#       dtype='object')

# %%
df['Strength'] = df['Strength'].str.replace(' mg','')

# %%
df['Strength'] = df['Strength'].astype(float)

# %%
df.groupby('Manufacturer')['Category'].value_counts()
# Out:
# Manufacturer                         Category
# AbbVie Inc.                          Antiseptic        334
#                                      Antidiabetic      333
#                                      Antifungal        326
#                                      Antidepressant    320
#                                      Antipyretic       316
#                                                       ...
# Teva Pharmaceutical Industries Ltd.  Antipyretic       315
#                                      Antibiotic        310
#                                      Analgesic         293
#                                      Antiviral         291
#                                      Antidepressant    290
# Name: count, Length: 160, dtype: int64

# %%
plt.figure(figsize=(25,25))
df.groupby('Manufacturer')['Category'].value_counts().plot(kind='bar')
plt.xticks(rotation=90)
plt.show()

# %%
df['Category'].value_counts()
# Out:
# Category
# Antidepressant    6354
# Analgesic         6340
# Antiseptic        6315
# Antifungal        6289
# Antipyretic       6280
# Antiviral         6185
# Antidiabetic      6171
# Antibiotic        6066
# Name: count, dtype: int64

# %%
df.groupby('Category')['Strength'].mean()
# Out:
# Category
# Analgesic         498.595584
# Antibiotic        496.547807
# Antidepressant    497.379918
# Antidiabetic      495.235456
# Antifungal        501.690571
# Antipyretic       500.877070
# Antiseptic        498.395724
# Antiviral         494.603234
# Name: Strength, dtype: float64

# %%
df.groupby('Dosage Form')['Strength'].mean()
# Out:
# Dosage Form
# Capsule      489.500558
# Cream        501.994804
# Drops        502.750962
# Inhaler      502.341609
# Injection    497.337648
# Ointment     492.058243
# Syrup        497.781598
# Tablet       499.766763
# Name: Strength, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Dosage Form'] = le.fit_transform(df['Dosage Form'])
df['Classification'] = le.fit_transform(df['Classification'])
df['Category'] = le.fit_transform(df['Category'])
df['Manufacturer'] = le.fit_transform(df['Manufacturer'])

# %%
df['Indication'] = le.fit_transform(df['Indication'])

# %%
df.head()
# Out:
#    Category  Dosage Form  Strength  Manufacturer  Indication  Classification
# 0         3            1     938.0            16           6               0
# 1         7            4     337.0             7           4               0
# 2         1            5     333.0            11           7               1
# 3         4            6     362.0             0           5               1
# 4         4            7     802.0            19           7               0

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr()*1000,annot=True, cmap='coolwarm')
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.boxplot(df)
plt.show()

# %%
X = df.drop('Classification',axis=1)
y = df['Classification']

# %%
df['Classification'].value_counts()
# Out:
# Classification
# 0    25015
# 1    24985
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier()
ada.fit(X_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred = ada.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.494

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[3271 2961]
#  [3364 2904]]

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.52      0.51      6232
#            1       0.50      0.46      0.48      6268
#
#     accuracy                           0.49     12500
#    macro avg       0.49      0.49      0.49     12500
# weighted avg       0.49      0.49      0.49     12500

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train_scaled,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred2 = rf.predict(X_test_scaled)

# %%
print(accuracy_score(y_test,y_pred2))
# Out:
# 0.50408

# %%
print(confusion_matrix(y_test,y_pred2))
# Out:
# [[3207 3025]
#  [3174 3094]]
